# %%
! pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 23.0.1 -> 23.1.2
# [notice] To update, run: C:\Users\kowsi\AppData\Local\Microsoft\WindowsApps\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\python.exe -m pip install --upgrade pip

# %% [markdown]
# # Data Understanding

# %% [markdown]
# ## Importing Libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
# %matplotlib inline

# %%
df_bat=pd.read_csv("BATTING STATS - IPL_2022.csv")

# %% [markdown]
# We Have Taken a Dataset Ipl-20222 , which Includes Both Batting and Bowling Performance of Each Player.

# %%
df_bat
# Out:
#      POS               Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  \
# 0      1          Jos Buttler   17    17   2   863   116  57.53  579  149.05
# 1      2            K L Rahul   15    15   3   616  103*  51.33  455  135.38
# 2      3      Quinton De Kock   15    15   1   508  140*  36.29  341  148.97
# 3      4        Hardik Pandya   15    15   4   487   87*  44.27  371  131.26
# 4      5         Shubman Gill   16    16   2   483    96   34.5  365  132.32
# ..   ...                  ...  ...   ...  ..   ...   ...    ...  ...     ...
# 157  158     Fazalhaq Farooqi    3     1   1     2    2*      -    8   25.00
# 158  159   Jagadeesha Suchith    5     2   0     2     2      1    8   25.00
# 159  160          Tim Southee    9     5   1     2    1*    0.5   12   16.66
# 160  161  Nathan Coulter-Nile    1     1   1     1    1*      -    2   50.00
# 161  162        Anrich Nortje    6     1   1     1    1*      -    6   16.66
#
#      100  50  4s  6s
# 0      4   4  83  45
# ...

# %%
df_bat.head(10)
# Out:
#    POS           Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0    1      Jos Buttler   17    17   2   863   116  57.53  579  149.05    4
# 1    2        K L Rahul   15    15   3   616  103*  51.33  455  135.38    2
# 2    3  Quinton De Kock   15    15   1   508  140*  36.29  341  148.97    1
# 3    4    Hardik Pandya   15    15   4   487   87*  44.27  371  131.26    0
# 4    5     Shubman Gill   16    16   2   483    96   34.5  365  132.32    0
# 5    6     David Miller   16    16   9   481   94*  68.71  337  142.72    0
# 6    7   Faf Du Plessis   16    16   1   468    96   31.2  367  127.52    0
# 7    8   Shikhar Dhawan   14    14   2   460   88*  38.33  375  122.66    0
# 8    9     Sanju Samson   17    17   1   458    55  28.63  312  146.79    0
# 9   10     Deepak Hooda   15    14   0   451    59  32.21  330  136.66    0
#
#    50  4s  6s
# 0   4  83  45
# 1   4  45  30
# 2   3  47  23
# 3   4  49  12
# 4   4  51  11
# 5   2  32  23
# 6   3  49  13
# ...

# %%
df_bat.tail(10)
# Out:
#      POS               Player  Mat  Inns  NO  Runs  HS  Avg  BF      SR  100  \
# 152  153          Shivam Mavi    6     3   1     3   2  1.5   7   42.85    0
# 153  154         Harshit Rana    2     2   1     2   2    2   2  100.00    0
# 154  155        Navdeep Saini    2     1   0     2   2    2   2  100.00    0
# 155  156       Tristan Stubbs    2     2   0     2   2    1   4   50.00    0
# 156  157      Pradeep Sangwan    3     1   0     2   2    2   5   40.00    0
# 157  158     Fazalhaq Farooqi    3     1   1     2  2*    -   8   25.00    0
# 158  159   Jagadeesha Suchith    5     2   0     2   2    1   8   25.00    0
# 159  160          Tim Southee    9     5   1     2  1*  0.5  12   16.66    0
# 160  161  Nathan Coulter-Nile    1     1   1     1  1*    -   2   50.00    0
# 161  162        Anrich Nortje    6     1   1     1  1*    -   6   16.66    0
#
#      50  4s  6s
# 152   0   0   0
# 153   0   0   0
# 154   0   0   0
# 155   0   0   0
# 156   0   0   0
# 157   0   0   0
# ...

# %%
df_bat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 162 entries, 0 to 161
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   POS     162 non-null    int64
#  1   Player  162 non-null    object
#  2   Mat     162 non-null    int64
#  3   Inns    162 non-null    int64
#  4   NO      162 non-null    int64
#  5   Runs    162 non-null    int64
#  6   HS      162 non-null    object
#  7   Avg     162 non-null    object
#  8   BF      162 non-null    int64
#  9   SR      162 non-null    float64
#  10  100     162 non-null    int64
#  11  50      162 non-null    int64
#  12  4s      162 non-null    int64
#  13  6s      162 non-null    int64
# dtypes: float64(1), int64(10), object(3)
# memory usage: 17.8+ KB

# %%
df_bat.nunique()
# Out:
# POS       162
# Player    162
# Mat        17
# Inns       17
# NO         10
# Runs      111
# HS        100
# Avg       119
# BF        111
# SR        143
# 100         4
# 50          6
# 4s         42
# 6s         28
# dtype: int64

# %%
df_bat.describe()
# Out:
#               POS         Mat        Inns          NO        Runs          BF  \
# count  162.000000  162.000000  162.000000  162.000000  162.000000  162.000000
# mean    81.500000    9.160494    7.141975    1.586420  142.296296  106.061728
# std     46.909487    5.047493    4.816982    1.819989  161.252161  114.571234
# min      1.000000    1.000000    1.000000    0.000000    1.000000    1.000000
# 25%     41.250000    5.000000    3.000000    0.000000   14.500000   14.000000
# 50%     81.500000    9.500000    7.000000    1.000000   65.000000   47.500000
# 75%    121.750000   14.000000   11.000000    2.000000  241.500000  176.500000
# max    162.000000   17.000000   17.000000   10.000000  863.000000  579.000000
#
#                SR         100          50          4s          6s
# count  162.000000  162.000000  162.000000  162.000000  162.000000
# mean   120.406235    0.049383    0.679012   12.450617    6.555556
# std     45.192799    0.366322    1.172428   15.314529    8.070343
# ...

# %%
df_bat.describe(include='all')
# Out:
#                POS       Player         Mat        Inns          NO  \
# count   162.000000          162  162.000000  162.000000  162.000000
# unique         NaN          162         NaN         NaN         NaN
# top            NaN  Jos Buttler         NaN         NaN         NaN
# freq           NaN            1         NaN         NaN         NaN
# mean     81.500000          NaN    9.160494    7.141975    1.586420
# std      46.909487          NaN    5.047493    4.816982    1.819989
# min       1.000000          NaN    1.000000    1.000000    0.000000
# 25%      41.250000          NaN    5.000000    3.000000    0.000000
# 50%      81.500000          NaN    9.500000    7.000000    1.000000
# 75%     121.750000          NaN   14.000000   11.000000    2.000000
# max     162.000000          NaN   17.000000   17.000000   10.000000
#
#               Runs   HS  Avg          BF          SR         100          50  \
# ...

# %%
type(df_bat)
# Out:
# pandas.core.frame.DataFrame

# %%
df_bat.columns
# Out:
# Index(['POS', 'Player', 'Mat', 'Inns', 'NO', 'Runs', 'HS', 'Avg', 'BF', 'SR',
#        '100', '50', '4s', '6s'],
#       dtype='object')

# %%
df_bat.shape
# Out:
# (162, 14)

# %% [markdown]
# # Index

# %%
df_bat[['Player','SR']]
# Out:
#                   Player      SR
# 0            Jos Buttler  149.05
# 1              K L Rahul  135.38
# 2        Quinton De Kock  148.97
# 3          Hardik Pandya  131.26
# 4           Shubman Gill  132.32
# ..                   ...     ...
# 157     Fazalhaq Farooqi   25.00
# 158   Jagadeesha Suchith   25.00
# 159          Tim Southee   16.66
# 160  Nathan Coulter-Nile   50.00
# 161        Anrich Nortje   16.66
#
# [162 rows x 2 columns]

# %%
df_bat.at[21, 'Player']
# Out:
# 'Virat Kohli'

# %%
df_bat.loc[30]
# Out:
# POS                  31
# Player    Glenn Maxwell
# Mat                  13
# Inns                 13
# NO                    2
# Runs                301
# HS                   55
# Avg               27.36
# BF                  178
# SR                169.1
# 100                   0
# 50                    1
# 4s                   31
# 6s                   15
# Name: 30, dtype: object

# %%
df_bat.SR.first_valid_index()
# Out:
# 0

# %%
df_bat.loc[20:31]
# Out:
#     POS            Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 20   21       Nitish Rana   14    14   1   361    57  27.77  251  143.82    0
# 21   22       Virat Kohli   16    16   1   341    73  22.73  294  115.98    0
# 22   23      Rishabh Pant   14    13   2   340    44  30.91  224  151.78    0
# 23   24     Andre Russell   14    12   3   335   70*  37.22  192  174.47    0
# 24   25     Rajat Patidar    8     7   1   333  112*   55.5  218  152.75    1
# 25   26    Dinesh Karthik   16    16  10   330   66*     55  180  183.33    0
# 26   27   Wriddhiman Saha   11    11   1   317    68   31.7  259  122.39    0
# 27   28   Shimron Hetmyer   15    15   8   314   59*  44.86  204  153.92    0
# 28   29   Nicholas Pooran   14    13   5   306   64*  38.25  212  144.33    0
# 29   30  Suryakumar Yadav    8     8   1   303   68*  43.29  208  145.67    0
# 30   31     Glenn Maxwell   13    13   2   301    55  27.36  178  169.10    0
# ...

# %%
df_bat.sample(10)
# Out:
#      POS            Player  Mat  Inns  NO  Runs   HS    Avg   BF      SR  100  \
# 102  103     James Neesham    2     2   0    31   17   15.5   27  114.81    0
# 122  123  Anmolpreet Singh    2     2   0    13    8    6.5   13  100.00    0
# 137  138       Ripal Patel    2     1   0     6    6      6    3  200.00    0
# 94    95   Hrithik Shokeen    5     3   1    43   25   21.5   48   89.58    0
# 33    34     Ambati Rayudu   13    11   0   274   78  24.91  224  122.32    0
# 90    91   Ramandeep Singh    5     4   2    45  14*   22.5   40  112.50    0
# 86    87       Odean Smith    6     6   3    51  25*     17   44  115.90    0
# 68    69   Ravindra Jadeja   10    10   4   116  26*  19.33   98  118.36    0
# 121  122      Simran Singh    1     1   0    14   14     14   11  127.27    0
# 35    36  Yashasvi Jaiswal   10    10   0   258   68   25.8  194  132.98    0
#
#      50  4s  6s
# 102   0   3   0
# 122   0   1   0
# 137   0   0   1
# 94    0   5   0
# 33    1  25  15
# ...

# %%
Total_runs=df_bat['Runs'].sum()
Total_runs
# Out:
# 23052

# %%
print('The Total Runs Scored in IPL 2022 Is {}'.format(Total_runs))
# Out:
# The Total Runs Scored in IPL 2022 Is 23052

# %%
Top_batsmen = df_bat.loc[df_bat['Runs'] >= 300]
Top_batsmen
# Out:
#     POS            Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  100  \
# 0     1       Jos Buttler   17    17   2   863   116  57.53  579  149.05    4
# 1     2         K L Rahul   15    15   3   616  103*  51.33  455  135.38    2
# 2     3   Quinton De Kock   15    15   1   508  140*  36.29  341  148.97    1
# 3     4     Hardik Pandya   15    15   4   487   87*  44.27  371  131.26    0
# 4     5      Shubman Gill   16    16   2   483    96   34.5  365  132.32    0
# 5     6      David Miller   16    16   9   481   94*  68.71  337  142.72    0
# 6     7    Faf Du Plessis   16    16   1   468    96   31.2  367  127.52    0
# 7     8    Shikhar Dhawan   14    14   2   460   88*  38.33  375  122.66    0
# 8     9      Sanju Samson   17    17   1   458    55  28.63  312  146.79    0
# 9    10      Deepak Hooda   15    14   0   451    59  32.21  330  136.66    0
# 10   11  Liam Livingstone   14    14   2   437    70  36.42  240  182.08    0
# ...

# %%
Power_Batsman = df_bat.loc[df_bat['6s'] > 10]
Power_Batsman
# Out:
#     POS             Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  \
# 0     1        Jos Buttler   17    17   2   863   116  57.53  579  149.05
# 1     2          K L Rahul   15    15   3   616  103*  51.33  455  135.38
# 2     3    Quinton De Kock   15    15   1   508  140*  36.29  341  148.97
# 3     4      Hardik Pandya   15    15   4   487   87*  44.27  371  131.26
# 4     5       Shubman Gill   16    16   2   483    96   34.5  365  132.32
# 5     6       David Miller   16    16   9   481   94*  68.71  337  142.72
# 6     7     Faf Du Plessis   16    16   1   468    96   31.2  367  127.52
# 7     8     Shikhar Dhawan   14    14   2   460   88*  38.33  375  122.66
# 8     9       Sanju Samson   17    17   1   458    55  28.63  312  146.79
# 9    10       Deepak Hooda   15    14   0   451    59  32.21  330  136.66
# 10   11   Liam Livingstone   14    14   2   437    70  36.42  240  182.08
# 11   12       David Warner   12    12   3   432   92*     48  287  150.52
# ...

# %%
Striker_Batsman=df_bat.loc[df_bat['SR']>140]
Striker_Batsman
# Out:
#      POS               Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  \
# 0      1          Jos Buttler   17    17   2   863   116  57.53  579  149.05
# 2      3      Quinton De Kock   15    15   1   508  140*  36.29  341  148.97
# 5      6         David Miller   16    16   9   481   94*  68.71  337  142.72
# 8      9         Sanju Samson   17    17   1   458    55  28.63  312  146.79
# 10    11     Liam Livingstone   14    14   2   437    70  36.42  240  182.08
# 11    12         David Warner   12    12   3   432   92*     48  287  150.52
# 14    15       Rahul Tripathi   14    14   3   413    76  37.55  261  158.23
# 20    21          Nitish Rana   14    14   1   361    57  27.77  251  143.82
# 22    23         Rishabh Pant   14    13   2   340    44  30.91  224  151.78
# 23    24        Andre Russell   14    12   3   335   70*  37.22  192  174.47
# 24    25        Rajat Patidar    8     7   1   333  112*   55.5  218  152.75
# ...

# %% [markdown]
# # Data Cleaning

# %%
df_bat.isnull().sum()
# Out:
# POS       0
# Player    0
# Mat       0
# Inns      0
# NO        0
# Runs      0
# HS        0
# Avg       0
# BF        0
# SR        0
# 100       0
# 50        0
# 4s        0
# 6s        0
# dtype: int64

# %%
bat=df_bat.fillna("0")
bat
# Out:
#      POS               Player  Mat  Inns  NO  Runs    HS    Avg   BF      SR  \
# 0      1          Jos Buttler   17    17   2   863   116  57.53  579  149.05
# 1      2            K L Rahul   15    15   3   616  103*  51.33  455  135.38
# 2      3      Quinton De Kock   15    15   1   508  140*  36.29  341  148.97
# 3      4        Hardik Pandya   15    15   4   487   87*  44.27  371  131.26
# 4      5         Shubman Gill   16    16   2   483    96   34.5  365  132.32
# ..   ...                  ...  ...   ...  ..   ...   ...    ...  ...     ...
# 157  158     Fazalhaq Farooqi    3     1   1     2    2*      -    8   25.00
# 158  159   Jagadeesha Suchith    5     2   0     2     2      1    8   25.00
# 159  160          Tim Southee    9     5   1     2    1*    0.5   12   16.66
# 160  161  Nathan Coulter-Nile    1     1   1     1    1*      -    2   50.00
# 161  162        Anrich Nortje    6     1   1     1    1*      -    6   16.66
#
#      100  50  4s  6s
# 0      4   4  83  45
# ...

# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## Univarient

# %%
fig, ((ax0, ax1)) = plt.subplots(nrows=1, ncols=2)
ax0.set_title("Histogram of Runs")
ax0.hist(df_bat.Runs);

ax1.set_title("Histogram of Strike Rate")
ax1.hist(df_bat.SR);

# %% [markdown]
# ## Bivarient

# %%
plt.figure(figsize=(10,5))
sns.barplot(x='SR', y='Player',hue='50', data=Top_batsmen.head(15))
plt.title('Top Batsman of IPL 2022')
plt.xlabel('Strike Rate')
plt.ylabel('Player')
plt.show()

# %%
import matplotlib.pyplot as plt

# create a bar chart of Runs by player
plt.figure(figsize=(10,5))
plt.bar(Top_batsmen['Player'][:5], Top_batsmen['Runs'][:5])
plt.title('Runs by player')
plt.xlabel('Player')
plt.ylabel('Runs')

plt.show()

# %%
import matplotlib.pyplot as plt

# sort the dataframe by Runs and select top 10 players
top10 = Top_batsmen.sort_values(by='Runs', ascending=False).head(10)

# create a horizontal bar chart of top 10 players by Runs
plt.barh(top10['Player'], top10['Runs'])
plt.title('Top 10 players by Runs')
plt.xlabel('Runs')
plt.ylabel('Player')

plt.show()

# %%
# create the line chart of Runs vs. Inns
plt.plot(Top_batsmen['Inns'], Top_batsmen['Runs'])
plt.title('Runs vs. Inns')
plt.xlabel('Innings')
plt.ylabel('Runs')
# Out:
# Text(0, 0.5, 'Runs')

# %%
sns.barplot(x='SR', y='Player', hue='100', data=Top_batsmen[:15]);
plt.title('Top Batsman of IPL 2022')
plt.xlabel('Strike Rate')
plt.ylabel('Player')
plt.show()

# %%
import seaborn as sns

# create a correlation matrix for the dataframe
corr_matrix = Top_batsmen.corr()

# plot the heatmap
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True)

plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\kowsi\AppData\Local\Temp\ipykernel_6964\3055854548.py:4: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = Top_batsmen.corr()

# %%
import seaborn as sns

# select the columns of interest
subset = Top_batsmen[['Mat', 'Runs', 'SR']]

# create a correlation matrix for the subset
corr_matrix = subset.corr()

# plot the heatmap
sns.heatmap(corr_matrix, cmap='coolwarm', annot=True)

plt.title('Correlation Matrix')
plt.show()

# %%
import seaborn as sns

# create a pivot table with Runs as values and Inns and Player as rows/columns
table = Top_batsmen.pivot_table(values='Runs', index='Inns', columns='Player')

# plot the heatmap
sns.heatmap(table, cmap='coolwarm', annot=True, fmt='g')

plt.title('Runs by Player and Innings')
plt.show()
